# %%
import pandas as pd

# %%
data = pd.read_csv('diabetes_012_health_indicators_BRFSS2015.csv', sep=',')
data = data.apply(pd.to_numeric, errors='coerce')
data = data.astype(int)
data = data.drop('Fruits', axis=1)
data = data.drop('Veggies', axis=1)
data = data.drop('AnyHealthcare', axis=1)
data = data.drop('NoDocbcCost', axis=1)

data
# Out:
#         Diabetes_012  HighBP  HighChol  BMI  Smoker  Stroke  \
# 0                  0       1         1   40       1       0
# 1                  0       0         0   25       1       0
# 2                  0       1         1   28       0       0
# 3                  0       1         0   27       0       0
# 4                  0       1         1   24       0       0
# ...              ...     ...       ...  ...     ...     ...
# 253675             0       1         1   45       0       0
# 253676             2       1         1   18       0       0
# 253677             0       0         0   28       0       0
# 253678             0       1         0   23       0       0
# 253679             2       1         1   25       0       0
#
#         HeartDiseaseorAttack  PhysActivity  HvyAlcoholConsump  GenHlth  \
# 0                          0             0                  0        5
# 1                          0             1                  0        3
# ...

# %%
range_col_names = ['BMI', 'MentHlth', 'PhysHlth']
quantiles_values = [[0.2, 0.4, 0.6, 0.8],[0.5], [0.5]]



for index in range(len(range_col_names)): 
    quantiles = data[range_col_names[index]].quantile(quantiles_values[index])
    ranges = [data[range_col_names[index]].min()] + quantiles.tolist() + [data[range_col_names[index]].max()]
    range_labels = [f'{int(ranges[i])}-{int(ranges[i+1])}' for i in range(len(ranges) - 1)]

    for i, range_label in enumerate(range_labels):
        min_val = ranges[i]
        max_val = ranges[i + 1]
        data[f'{range_col_names[index]}_{range_label}'] = ((data[range_col_names[index]] >= min_val) & (data[range_col_names[index]] < max_val)).astype(int)

    data.drop(columns=[range_col_names[index]], inplace=True)


data
# Out:
#         Diabetes_012  HighBP  HighChol  Smoker  Stroke  HeartDiseaseorAttack  \
# 0                  0       1         1       1       0                     0
# 1                  0       0         0       1       0                     0
# 2                  0       1         1       0       0                     0
# 3                  0       1         0       0       0                     0
# 4                  0       1         1       0       0                     0
# ...              ...     ...       ...     ...     ...                   ...
# 253675             0       1         1       0       0                     0
# 253676             2       1         1       0       0                     0
# 253677             0       0         0       0       0                     0
# 253678             0       1         0       0       0                     0
# 253679             2       1         1       0       0                     1
#
# ...

# %%
dumie_col_names = ['GenHlth', 'Age', 'Education', 'Income']

for col in dumie_col_names:
    dummies = pd.get_dummies(data[col], prefix=f'{col}_')
    dummies = dummies.astype(int)
    data = pd.concat([data, dummies], axis=1)
    data.drop(columns=[col], inplace=True)

data
# Out:
#         Diabetes_012  HighBP  HighChol  Smoker  Stroke  HeartDiseaseorAttack  \
# 0                  0       1         1       1       0                     0
# 1                  0       0         0       1       0                     0
# 2                  0       1         1       0       0                     0
# 3                  0       1         0       0       0                     0
# 4                  0       1         1       0       0                     0
# ...              ...     ...       ...     ...     ...                   ...
# 253675             0       1         1       0       0                     0
# 253676             2       1         1       0       0                     0
# 253677             0       0         0       0       0                     0
# 253678             0       1         0       0       0                     0
# 253679             2       1         1       0       0                     1
#
# ...

# %%
data.to_csv('output.csv', index=False)
